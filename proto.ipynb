# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

# %%
# def get_all_links(base_url):
#     visited = set()
#     to_visit = [base_url]
#     all_links = []

#     while to_visit:
#         url = to_visit.pop(0)
#         if url in visited:
#             continue
#         visited.add(url)

#         try:
#             response = requests.get(url)
#             response.raise_for_status()
#             soup = BeautifulSoup(response.text, 'html.parser')
#             for link in soup.find_all('a', href=True):
#                 href = link['href']
#                 full_url = urljoin(base_url, href)
#                 if urlparse(full_url).netloc == urlparse(base_url).netloc:
#                     if full_url not in visited:
#                         to_visit.append(full_url)
#                     all_links.append(full_url)
#         except requests.RequestException:
#             continue

#     return all_links

def crawl_domain(start_url):
    # Normalize the start URL
    if not start_url.startswith('http'):
        start_url = 'http://' + start_url
    
    domain = urlparse(start_url).netloc
    crawled_urls = set()
    to_crawl = [start_url]

    while to_crawl:
        current_url = to_crawl.pop(0)
        
        if current_url not in crawled_urls:
            try:
                response = requests.get(current_url)
                if response.status_code == 200:
                    soup = BeautifulSoup(response.text, 'html.parser')
                    
                    crawled_urls.add(current_url)
                    print(f"Crawled: {current_url}")

                    for link in soup.find_all('a'):
                        href = link.get('href')
                        if href:
                            full_url = urljoin(current_url, href)
                            if urlparse(full_url).netloc == domain and full_url not in crawled_urls:
                                to_crawl.append(full_url)
            except Exception as e:
                print(f"Error crawling {current_url}: {e}")

    return list(crawled_urls)

# %%
site_url = 'https://manjushreefinance.com.np'
links = crawl_domain(site_url)
for link in links:
    print(link)
# Out:
# Crawled: https://manjushreefinance.com.np
# Crawled: https://manjushreefinance.com.np/page/company-profile
# Crawled: https://manjushreefinance.com.np/page/capital-structure
# Crawled: https://manjushreefinance.com.np/team/board-of-directors
# Crawled: https://manjushreefinance.com.np/team/management
# Crawled: https://manjushreefinance.com.np/team/information-officer
# Crawled: https://manjushreefinance.com.np/team/compliance-officer
# Crawled: https://manjushreefinance.com.np/deposit
# Crawled: https://manjushreefinance.com.np/loan
# Crawled: https://manjushreefinance.com.np/digital-banking
# Crawled: https://manjushreefinance.com.np/other-services
# Crawled: https://manjushreefinance.com.np/rates/interest-rate
# Crawled: https://manjushreefinance.com.np/rates/fee-and-charges
# Crawled: https://manjushreefinance.com.np/rates/base-and-spread-rate
# Crawled: https://manjushreefinance.com.np/reports/basel-reports
# Crawled: https://manjushreefinance.com.np/reports/quarterly-reports
# Crawled: https://manjushreefinance.com.np/reports/annual-reports
# Crawled: https://manjushreefinance.com.np/downloads
# Crawled: https://manjushreefinance.com.np/contact
# Crawled: https://manjushreefinance.com.np/notices
# Crawled: https://manjushreefinance.com.np/branch
# Crawled: https://manjushreefinance.com.np/atm
# Crawled: https://manjushreefinance.com.np/career
# Crawled: https://manjushreefinance.com.np#deposit
# Crawled: https://manjushreefinance.com.np#loan
# Crawled: https://manjushreefinance.com.np#digital-banking
# Crawled: https://manjushreefinance.com.np#other-services
# Crawled: https://manjushreefinance.com.np/detail/515/manjushree-talab-bachat-khata-2024-Jul-16-238600
# Crawled: https://manjushreefinance.com.np/detail/409/naulo-remit-saving
# Crawled: https://manjushreefinance.com.np/detail/400/premium-saving-
# Crawled: https://manjushreefinance.com.np/detail/240/bishesh-bachat-
# Crawled: https://manjushreefinance.com.np/detail/225/nari-saving
# Crawled: https://manjushreefinance.com.np/detail/72/fixed-deposits
# Crawled: https://manjushreefinance.com.np/detail/226/home-loan
# Crawled: https://manjushreefinance.com.np/detail/149/share-loan
# Crawled: https://manjushreefinance.com.np/detail/150/education-loan
# Crawled: https://manjushreefinance.com.np/detail/152/auto-loan
# Crawled: https://manjushreefinance.com.np/detail/156/business-loan
# Crawled: https://manjushreefinance.com.np/detail/410/manjushree-smart-teller
# Crawled: https://manjushreefinance.com.np/detail/232/connectip
# Crawled: https://manjushreefinance.com.np/detail/144/debit-card
# Crawled: https://manjushreefinance.com.np/detail/136/mobile-banking
# Crawled: https://manjushreefinance.com.np/detail/154/c-asba
# Crawled: https://manjushreefinance.com.np/detail/155/ips-&-clearing
# Crawled: https://manjushreefinance.com.np/detail/139/remittance
# Crawled: https://manjushreefinance.com.np#deposit-1
# Crawled: https://manjushreefinance.com.np#loan-2
# Crawled: https://manjushreefinance.com.np#digital-banking-3
# Crawled: https://manjushreefinance.com.np#other-services-4
# Crawled: https://manjushreefinance.com.np/detail/70/normal-saving
# Crawled: https://manjushreefinance.com.np/detail/73/children-saving
# Crawled: https://manjushreefinance.com.np/products
# Crawled: https://manjushreefinance.com.np/video-tutorial
# Crawled: https://manjushreefinance.com.np/news-event
# Crawled: https://manjushreefinance.com.np/feedback
# Crawled: https://manjushreefinance.com.np/uploads/acf/85148200.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/03058900.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/29416400.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1690431814.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/02583300.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/99088900.pdf
# Crawled: https://manjushreefinance.com.np/page/company-profile#deposit
# Crawled: https://manjushreefinance.com.np/page/company-profile#loan
# Crawled: https://manjushreefinance.com.np/page/company-profile#digital-banking
# Crawled: https://manjushreefinance.com.np/page/company-profile#other-services
# Crawled: https://manjushreefinance.com.np/page/capital-structure#deposit
# Crawled: https://manjushreefinance.com.np/page/capital-structure#loan
# Crawled: https://manjushreefinance.com.np/page/capital-structure#digital-banking
# Crawled: https://manjushreefinance.com.np/page/capital-structure#other-services
# Crawled: https://manjushreefinance.com.np/team/board-of-directors#deposit
# Crawled: https://manjushreefinance.com.np/team/board-of-directors#loan
# Crawled: https://manjushreefinance.com.np/team/board-of-directors#digital-banking
# Crawled: https://manjushreefinance.com.np/team/board-of-directors#other-services
# Crawled: https://manjushreefinance.com.np/team/management#deposit
# Crawled: https://manjushreefinance.com.np/team/management#loan
# Crawled: https://manjushreefinance.com.np/team/management#digital-banking
# Crawled: https://manjushreefinance.com.np/team/management#other-services
# Crawled: https://manjushreefinance.com.np/team/information-officer#deposit
# Crawled: https://manjushreefinance.com.np/team/information-officer#loan
# Crawled: https://manjushreefinance.com.np/team/information-officer#digital-banking
# Crawled: https://manjushreefinance.com.np/team/information-officer#other-services
# Crawled: https://manjushreefinance.com.np/team/compliance-officer#deposit
# Crawled: https://manjushreefinance.com.np/team/compliance-officer#loan
# Crawled: https://manjushreefinance.com.np/team/compliance-officer#digital-banking
# Crawled: https://manjushreefinance.com.np/team/compliance-officer#other-services
# Crawled: https://manjushreefinance.com.np/deposit#deposit
# Crawled: https://manjushreefinance.com.np/deposit#loan
# Crawled: https://manjushreefinance.com.np/deposit#digital-banking
# Crawled: https://manjushreefinance.com.np/deposit#other-services
# Crawled: https://manjushreefinance.com.np/loan#deposit
# Crawled: https://manjushreefinance.com.np/loan#loan
# Crawled: https://manjushreefinance.com.np/loan#digital-banking
# Crawled: https://manjushreefinance.com.np/loan#other-services
# Crawled: https://manjushreefinance.com.np/digital-banking#deposit
# Crawled: https://manjushreefinance.com.np/digital-banking#loan
# Crawled: https://manjushreefinance.com.np/digital-banking#digital-banking
# Crawled: https://manjushreefinance.com.np/digital-banking#other-services
# Crawled: https://manjushreefinance.com.np/other-services#deposit
# Crawled: https://manjushreefinance.com.np/other-services#loan
# Crawled: https://manjushreefinance.com.np/other-services#digital-banking
# Crawled: https://manjushreefinance.com.np/other-services#other-services
# Crawled: https://manjushreefinance.com.np/rates/interest-rate#deposit
# Crawled: https://manjushreefinance.com.np/rates/interest-rate#loan
# Crawled: https://manjushreefinance.com.np/rates/interest-rate#digital-banking
# Crawled: https://manjushreefinance.com.np/rates/interest-rate#other-services
# Crawled: https://manjushreefinance.com.np/rates/fee-and-charges#deposit
# Crawled: https://manjushreefinance.com.np/rates/fee-and-charges#loan
# Crawled: https://manjushreefinance.com.np/rates/fee-and-charges#digital-banking
# Crawled: https://manjushreefinance.com.np/rates/fee-and-charges#other-services
# Crawled: https://manjushreefinance.com.np/rates/base-and-spread-rate#deposit
# Crawled: https://manjushreefinance.com.np/rates/base-and-spread-rate#loan
# Crawled: https://manjushreefinance.com.np/rates/base-and-spread-rate#digital-banking
# Crawled: https://manjushreefinance.com.np/rates/base-and-spread-rate#other-services
# Crawled: https://manjushreefinance.com.np/reports/basel-reports#deposit
# Crawled: https://manjushreefinance.com.np/reports/basel-reports#loan
# Crawled: https://manjushreefinance.com.np/reports/basel-reports#digital-banking
# Crawled: https://manjushreefinance.com.np/reports/basel-reports#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Jul-16-2024-Aug-14-657300
# Crawled: https://manjushreefinance.com.np/uploads/acf/66270600.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Apr-13-2024-Aug-14-055900
# Crawled: https://manjushreefinance.com.np/uploads/acf/06165400.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Dec-15-2024-Aug-14-978800
# Crawled: https://manjushreefinance.com.np/uploads/acf/98505100.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2023-Nov-09-560000
# Crawled: https://manjushreefinance.com.np/uploads/acf/56696800.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2080
# Crawled: https://manjushreefinance.com.np/uploads/acf/1691653912.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2079
# Crawled: https://manjushreefinance.com.np/uploads/acf/1660818096.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ll-report-as-of-chaitra-2078
# Crawled: https://manjushreefinance.com.np/uploads/acf/1655961231.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2078
# Crawled: https://manjushreefinance.com.np/uploads/acf/1643175324.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-for-the-ashoj-2078
# Crawled: https://manjushreefinance.com.np/uploads/acf/1637295925.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-asar--2078
# Crawled: https://manjushreefinance.com.np/uploads/acf/1628575553.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-for-the-chaitra--2077
# Crawled: https://manjushreefinance.com.np/uploads/acf/1619504991.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2077
# Crawled: https://manjushreefinance.com.np/uploads/acf/1617260452.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-ashwin--2077
# Crawled: https://manjushreefinance.com.np/uploads/acf/1606805381.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report--as-of-ashad-2077
# Crawled: https://manjushreefinance.com.np/uploads/acf/1596972048.pdf
# Crawled: https://manjushreefinance.com.np/reports/quarterly-reports#deposit
# Crawled: https://manjushreefinance.com.np/reports/quarterly-reports#loan
# Crawled: https://manjushreefinance.com.np/reports/quarterly-reports#digital-banking
# Crawled: https://manjushreefinance.com.np/reports/quarterly-reports#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-208081-as-per-nfrs-2024-Aug-14-600500
# Crawled: https://manjushreefinance.com.np/uploads/acf/61275800.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-208081-published-2024-Aug-06-729200
# Crawled: https://manjushreefinance.com.np/uploads/acf/69546200.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-208081-as-per-nfrs-2024-May-07-005100
# Crawled: https://manjushreefinance.com.np/uploads/acf/46748300.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-208081-published-2024-Apr-21-000100
# Crawled: https://manjushreefinance.com.np/uploads/acf/97511700.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-208081-as-per-nfrs-2024-Jan-26-058000
# Crawled: https://manjushreefinance.com.np/uploads/acf/06403400.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-208081-published-2024-Jan-21-413600
# Crawled: https://manjushreefinance.com.np/uploads/acf/25553000.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-208081-as-per-nfrs-2023-Nov-09-367900
# Crawled: https://manjushreefinance.com.np/uploads/acf/37638300.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fiscal-year-208081
# Crawled: https://manjushreefinance.com.np/uploads/acf/51536000.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2079-80-as-per-nrfs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1691667621.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2079-80---published
# Crawled: https://manjushreefinance.com.np/uploads/acf/1691303181.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2079-80---published
# Error crawling https://manjushreefinance.com.np/uploads/acf/1682252362.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  unknown status keyword 'b' in marked section
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quaterly-report-2079-80---published
# Crawled: https://manjushreefinance.com.np/uploads/acf/1674269382.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quaterly-report-2079-80---published
# Crawled: https://manjushreefinance.com.np/uploads/acf/1667279335.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2078-79--as-per-nfrs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1660820436.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quaterly-report-2078-79-published
# Crawled: https://manjushreefinance.com.np/uploads/acf/1659868991.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quaterly-report-2078-79-as-per-nfrs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1650529585.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2078-79---published
# Crawled: https://manjushreefinance.com.np/uploads/acf/1650427359.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2078-79-as-per-nfrs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1643276459.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2078-79---published
# Crawled: https://manjushreefinance.com.np/uploads/acf/1642738591.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2078-79-as-per-nfrs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1638857063.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2078-79----published
# Crawled: https://manjushreefinance.com.np/uploads/acf/1635740382.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/forth-quarterly-report-2077-78-as-per-nfrs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1628586349.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2077-78
# Crawled: https://manjushreefinance.com.np/uploads/acf/1628498019.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2077-78-as-per-nfrs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1619505461.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2077-78
# Crawled: https://manjushreefinance.com.np/uploads/acf/1618991060.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2077-78-as-per-nrfs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1617262557.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2077-78
# Crawled: https://manjushreefinance.com.np/uploads/acf/1611729804.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2077-78-as-per-nrfs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1606903273.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2077-78
# Crawled: https://manjushreefinance.com.np/uploads/acf/1605629560.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2076-77-as-per-nrfs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1596695335.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2076-77
# Crawled: https://manjushreefinance.com.np/uploads/acf/1595221439.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2076-77-as-per-nrfs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1590320056.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2076-77
# Crawled: https://manjushreefinance.com.np/uploads/acf/1588581411.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2076-77-as-per-nrfs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1582176797.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2076-77
# Crawled: https://manjushreefinance.com.np/uploads/acf/1579410032.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2076-77-as-per-nrfs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1574145643.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2076-77
# Crawled: https://manjushreefinance.com.np/uploads/acf/1573728318.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2064-65
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563254930.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![���aFe\x0b�\x0b�g�\x1d\x15�W�'
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2065-66
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563254976.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2065-66
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255000.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2065-66
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563255020.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![���aFe\x0b�\x0b�g�\x1d\x15�W�'
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2065-66
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563255041.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![��C\x18��+�j\x15ڕ��R��\x16'
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2066-67
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255105.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2066-67
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255123.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2066-67
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255142.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2066-67
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255159.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2067-68
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255232.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2067-68
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255252.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2067-68
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255279.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2067-68
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255306.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2068-69
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255345.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second--quarterly-report--2068-69
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255370.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2068-69
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255401.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2068-69
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255420.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2069-70
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255462.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2069-70
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255481.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2069-70
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255513.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2069-70
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255534.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2070-71
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255562.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2070-71
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255587.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2070-71
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255610.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2070-71
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255630.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2071-72
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255691.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2071-72
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255801.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2071-72
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255820.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2071-72
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255840.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2072-73
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255887.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2072-73
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255911.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2072-73
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255932.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2072-73
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563255955.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2073-74
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563095016.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2073-74
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563095039.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2073-74
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563095056.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2073-74
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563095072.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/manjushree
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563094729.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2074-75
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563094751.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2074-75
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563094778.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/manjusghree
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563094805.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2075-76-as-per-nrfs
# Crawled: https://manjushreefinance.com.np/uploads/acf/1568281534.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2075-76
# Crawled: https://manjushreefinance.com.np/uploads/acf/1565849204.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2075-76
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563257278.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2075-76
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563257239.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2075-76
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563257259.pdf
# Crawled: https://manjushreefinance.com.np/reports/annual-reports#deposit
# Crawled: https://manjushreefinance.com.np/reports/annual-reports#loan
# Crawled: https://manjushreefinance.com.np/reports/annual-reports#digital-banking
# Crawled: https://manjushreefinance.com.np/reports/annual-reports#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/sixteenth-annual-report-2079080-2024-Jan-08-500900
# Crawled: https://manjushreefinance.com.np/uploads/acf/51615400.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fifteenth-annual-report
# Crawled: https://manjushreefinance.com.np/uploads/acf/1672916364.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourteenth-annual-report-%282077-78%29
# Crawled: https://manjushreefinance.com.np/uploads/acf/1642672845.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/thirteenth-annual-report
# Crawled: https://manjushreefinance.com.np/uploads/acf/1610004166.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/twelve-annual-report-%282075-76%29
# Crawled: https://manjushreefinance.com.np/uploads/acf/1578641016.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/eleventh-annual-report
# Crawled: https://manjushreefinance.com.np/uploads/acf/1566897880.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/tenth-annual-report
# Crawled: https://manjushreefinance.com.np/uploads/acf/1566897841.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/ninth-annual-report
# Crawled: https://manjushreefinance.com.np/uploads/acf/1566897745.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/eighth-annual-report
# Crawled: https://manjushreefinance.com.np/uploads/acf/1566897551.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/seventh-annual-report
# Crawled: https://manjushreefinance.com.np/uploads/acf/1566895827.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/sixth-annual-report
# Crawled: https://manjushreefinance.com.np/uploads/acf/1566890488.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fifth-annual-report
# Crawled: https://manjushreefinance.com.np/uploads/acf/1566890339.pdf
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-annual-report
# Crawled: https://manjushreefinance.com.np/uploads/acf/1566890176.pdf
# Crawled: https://manjushreefinance.com.np/downloads#deposit
# Crawled: https://manjushreefinance.com.np/downloads#loan
# Crawled: https://manjushreefinance.com.np/downloads#digital-banking
# Crawled: https://manjushreefinance.com.np/downloads#other-services
# Crawled: https://manjushreefinance.com.np/uploads/acf/1679223322.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1666248502.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1624426669.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1593322464.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1593322642.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1615283214.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563083348.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1563083669.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/97281500.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1561445494.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1561446430.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1561446462.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1683631796.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1610880785.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1597662805.pdf
# Crawled: https://manjushreefinance.com.np/uploads/acf/1576405988.pdf
# Crawled: https://manjushreefinance.com.np/contact#deposit
# Crawled: https://manjushreefinance.com.np/contact#loan
# Crawled: https://manjushreefinance.com.np/contact#digital-banking
# Crawled: https://manjushreefinance.com.np/contact#other-services
# Crawled: https://manjushreefinance.com.np/notices#deposit
# Crawled: https://manjushreefinance.com.np/notices#loan
# Crawled: https://manjushreefinance.com.np/notices#digital-banking
# Crawled: https://manjushreefinance.com.np/notices#other-services
# Crawled: https://manjushreefinance.com.np/detail/512/web-banking-2024-Jun-11-235100
# Crawled: https://manjushreefinance.com.np/detail/490/election-schedule-2023-Dec-27-925900
# Crawled: https://manjushreefinance.com.np/detail/489/16th-agm-notice-2023-Dec-20-183200
# Crawled: https://manjushreefinance.com.np/branch#deposit
# Crawled: https://manjushreefinance.com.np/branch#loan
# Crawled: https://manjushreefinance.com.np/branch#digital-banking
# Crawled: https://manjushreefinance.com.np/branch#other-services
# Crawled: https://manjushreefinance.com.np/atm#deposit
# Crawled: https://manjushreefinance.com.np/atm#loan
# Crawled: https://manjushreefinance.com.np/atm#digital-banking
# Crawled: https://manjushreefinance.com.np/atm#other-services
# Crawled: https://manjushreefinance.com.np/career#deposit
# Crawled: https://manjushreefinance.com.np/career#loan
# Crawled: https://manjushreefinance.com.np/career#digital-banking
# Crawled: https://manjushreefinance.com.np/career#other-services
# Crawled: https://manjushreefinance.com.np/detail/515/manjushree-talab-bachat-khata-2024-Jul-16-238600#deposit
# Crawled: https://manjushreefinance.com.np/detail/515/manjushree-talab-bachat-khata-2024-Jul-16-238600#loan
# Crawled: https://manjushreefinance.com.np/detail/515/manjushree-talab-bachat-khata-2024-Jul-16-238600#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/515/manjushree-talab-bachat-khata-2024-Jul-16-238600#other-services
# Crawled: https://manjushreefinance.com.np/detail/71/saving-plus-
# Crawled: https://manjushreefinance.com.np/detail/409/naulo-remit-saving#deposit
# Crawled: https://manjushreefinance.com.np/detail/409/naulo-remit-saving#loan
# Crawled: https://manjushreefinance.com.np/detail/409/naulo-remit-saving#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/409/naulo-remit-saving#other-services
# Crawled: https://manjushreefinance.com.np/detail/400/premium-saving-#deposit
# Crawled: https://manjushreefinance.com.np/detail/400/premium-saving-#loan
# Crawled: https://manjushreefinance.com.np/detail/400/premium-saving-#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/400/premium-saving-#other-services
# Crawled: https://manjushreefinance.com.np/detail/240/bishesh-bachat-#deposit
# Crawled: https://manjushreefinance.com.np/detail/240/bishesh-bachat-#loan
# Crawled: https://manjushreefinance.com.np/detail/240/bishesh-bachat-#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/240/bishesh-bachat-#other-services
# Crawled: https://manjushreefinance.com.np/detail/225/nari-saving#deposit
# Crawled: https://manjushreefinance.com.np/detail/225/nari-saving#loan
# Crawled: https://manjushreefinance.com.np/detail/225/nari-saving#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/225/nari-saving#other-services
# Crawled: https://manjushreefinance.com.np/detail/72/fixed-deposits#deposit
# Crawled: https://manjushreefinance.com.np/detail/72/fixed-deposits#loan
# Crawled: https://manjushreefinance.com.np/detail/72/fixed-deposits#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/72/fixed-deposits#other-services
# Crawled: https://manjushreefinance.com.np/detail/226/home-loan#deposit
# Crawled: https://manjushreefinance.com.np/detail/226/home-loan#loan
# Crawled: https://manjushreefinance.com.np/detail/226/home-loan#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/226/home-loan#other-services
# Crawled: https://manjushreefinance.com.np/detail/149/share-loan#deposit
# Crawled: https://manjushreefinance.com.np/detail/149/share-loan#loan
# Crawled: https://manjushreefinance.com.np/detail/149/share-loan#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/149/share-loan#other-services
# Crawled: https://manjushreefinance.com.np/detail/150/education-loan#deposit
# Crawled: https://manjushreefinance.com.np/detail/150/education-loan#loan
# Crawled: https://manjushreefinance.com.np/detail/150/education-loan#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/150/education-loan#other-services
# Crawled: https://manjushreefinance.com.np/detail/152/auto-loan#deposit
# Crawled: https://manjushreefinance.com.np/detail/152/auto-loan#loan
# Crawled: https://manjushreefinance.com.np/detail/152/auto-loan#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/152/auto-loan#other-services
# Crawled: https://manjushreefinance.com.np/detail/156/business-loan#deposit
# Crawled: https://manjushreefinance.com.np/detail/156/business-loan#loan
# Crawled: https://manjushreefinance.com.np/detail/156/business-loan#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/156/business-loan#other-services
# Crawled: https://manjushreefinance.com.np/detail/410/manjushree-smart-teller#deposit
# Crawled: https://manjushreefinance.com.np/detail/410/manjushree-smart-teller#loan
# Crawled: https://manjushreefinance.com.np/detail/410/manjushree-smart-teller#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/410/manjushree-smart-teller#other-services
# Crawled: https://manjushreefinance.com.np/detail/232/connectip#deposit
# Crawled: https://manjushreefinance.com.np/detail/232/connectip#loan
# Crawled: https://manjushreefinance.com.np/detail/232/connectip#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/232/connectip#other-services
# Crawled: https://manjushreefinance.com.np/detail/144/debit-card#deposit
# Crawled: https://manjushreefinance.com.np/detail/144/debit-card#loan
# Crawled: https://manjushreefinance.com.np/detail/144/debit-card#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/144/debit-card#other-services
# Crawled: https://manjushreefinance.com.np/detail/136/mobile-banking#deposit
# Crawled: https://manjushreefinance.com.np/detail/136/mobile-banking#loan
# Crawled: https://manjushreefinance.com.np/detail/136/mobile-banking#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/136/mobile-banking#other-services
# Crawled: https://manjushreefinance.com.np/detail/154/c-asba#deposit
# Crawled: https://manjushreefinance.com.np/detail/154/c-asba#loan
# Crawled: https://manjushreefinance.com.np/detail/154/c-asba#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/154/c-asba#other-services
# Crawled: https://manjushreefinance.com.np/detail/155/ips-&-clearing#deposit
# Crawled: https://manjushreefinance.com.np/detail/155/ips-&-clearing#loan
# Crawled: https://manjushreefinance.com.np/detail/155/ips-&-clearing#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/155/ips-&-clearing#other-services
# Crawled: https://manjushreefinance.com.np/detail/139/remittance#deposit
# Crawled: https://manjushreefinance.com.np/detail/139/remittance#loan
# Crawled: https://manjushreefinance.com.np/detail/139/remittance#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/139/remittance#other-services
# Crawled: https://manjushreefinance.com.np/detail/70/normal-saving#deposit
# Crawled: https://manjushreefinance.com.np/detail/70/normal-saving#loan
# Crawled: https://manjushreefinance.com.np/detail/70/normal-saving#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/70/normal-saving#other-services
# Crawled: https://manjushreefinance.com.np/detail/73/children-saving#deposit
# Crawled: https://manjushreefinance.com.np/detail/73/children-saving#loan
# Crawled: https://manjushreefinance.com.np/detail/73/children-saving#digital-banking
# Crawled: https://manjushreefinance.com.np/detail/73/children-saving#other-services
# Crawled: https://manjushreefinance.com.np/products#deposit
# Crawled: https://manjushreefinance.com.np/products#loan
# Crawled: https://manjushreefinance.com.np/products#digital-banking
# Crawled: https://manjushreefinance.com.np/products#other-services
# Crawled: https://manjushreefinance.com.np/video-tutorial#deposit
# Crawled: https://manjushreefinance.com.np/video-tutorial#loan
# Crawled: https://manjushreefinance.com.np/video-tutorial#digital-banking
# Crawled: https://manjushreefinance.com.np/video-tutorial#other-services
# Crawled: https://manjushreefinance.com.np/news-event#deposit
# Crawled: https://manjushreefinance.com.np/news-event#loan
# Crawled: https://manjushreefinance.com.np/news-event#digital-banking
# Crawled: https://manjushreefinance.com.np/news-event#other-services
# Crawled: https://manjushreefinance.com.np/feedback#deposit
# Crawled: https://manjushreefinance.com.np/feedback#loan
# Crawled: https://manjushreefinance.com.np/feedback#digital-banking
# Crawled: https://manjushreefinance.com.np/feedback#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Jul-16-2024-Aug-14-657300#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Jul-16-2024-Aug-14-657300#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Jul-16-2024-Aug-14-657300#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Jul-16-2024-Aug-14-657300#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Apr-13-2024-Aug-14-055900#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Apr-13-2024-Aug-14-055900#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Apr-13-2024-Aug-14-055900#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Apr-13-2024-Aug-14-055900#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Dec-15-2024-Aug-14-978800#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Dec-15-2024-Aug-14-978800#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Dec-15-2024-Aug-14-978800#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Dec-15-2024-Aug-14-978800#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2023-Nov-09-560000#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2023-Nov-09-560000#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2023-Nov-09-560000#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/fy-208081-2023-Nov-09-560000#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2080#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2080#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2080#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2080#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2079#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2079#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2079#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2079#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ll-report-as-of-chaitra-2078#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ll-report-as-of-chaitra-2078#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ll-report-as-of-chaitra-2078#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ll-report-as-of-chaitra-2078#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2078#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2078#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2078#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2078#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-for-the-ashoj-2078#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-for-the-ashoj-2078#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-for-the-ashoj-2078#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-for-the-ashoj-2078#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-asar--2078#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-asar--2078#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-asar--2078#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-asar--2078#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-for-the-chaitra--2077#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-for-the-chaitra--2077#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-for-the-chaitra--2077#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-for-the-chaitra--2077#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2077#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2077#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2077#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2077#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-ashwin--2077#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-ashwin--2077#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-ashwin--2077#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-ashwin--2077#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report--as-of-ashad-2077#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report--as-of-ashad-2077#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report--as-of-ashad-2077#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/basel-ii-report--as-of-ashad-2077#other-services
# Error crawling https://manjushreefinance.com.np/uploads/acf/1682252362.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  unknown status keyword 'b' in marked section
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563254930.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![���aFe\x0b�\x0b�g�\x1d\x15�W�'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563255020.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![���aFe\x0b�\x0b�g�\x1d\x15�W�'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563255041.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![��C\x18��+�j\x15ڕ��R��\x16'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1682252362.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  unknown status keyword 'b' in marked section
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563254930.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![���aFe\x0b�\x0b�g�\x1d\x15�W�'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563255020.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![���aFe\x0b�\x0b�g�\x1d\x15�W�'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563255041.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![��C\x18��+�j\x15ڕ��R��\x16'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1682252362.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  unknown status keyword 'b' in marked section
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563254930.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![���aFe\x0b�\x0b�g�\x1d\x15�W�'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563255020.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![���aFe\x0b�\x0b�g�\x1d\x15�W�'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563255041.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![��C\x18��+�j\x15ڕ��R��\x16'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1682252362.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  unknown status keyword 'b' in marked section
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563254930.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![���aFe\x0b�\x0b�g�\x1d\x15�W�'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563255020.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![���aFe\x0b�\x0b�g�\x1d\x15�W�'
# Error crawling https://manjushreefinance.com.np/uploads/acf/1563255041.pdf: The markup you provided was rejected by the parser. Trying a different parser or a different encoding may help.
#
# Original exception(s) from parser:
#  expected name token at '<![��C\x18��+�j\x15ڕ��R��\x16'
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-208081-as-per-nfrs-2024-Aug-14-600500#deposit
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-208081-as-per-nfrs-2024-Aug-14-600500#loan
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-208081-as-per-nfrs-2024-Aug-14-600500#digital-banking
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-208081-as-per-nfrs-2024-Aug-14-600500#other-services
# Crawled: https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-208081-published-2024-Aug-06-729200#deposit
# ...
# https://manjushreefinance.com.np/team/board-of-directors#loan
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2073-74#loan
# https://manjushreefinance.com.np/detail/225/nari-saving#digital-banking
# https://manjushreefinance.com.np/detail/410/manjushree-smart-teller#loan
# https://manjushreefinance.com.np/report-viewer/basel-ii-report--as-of-ashad-2077#loan
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-208081-as-per-nfrs-2024-Aug-14-600500#other-services
# https://manjushreefinance.com.np/report-viewer/fifth-annual-report#digital-banking
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2078-79----published#deposit
# https://manjushreefinance.com.np/loan#other-services
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2067-68#other-services
# https://manjushreefinance.com.np/contact
# https://manjushreefinance.com.np/feedback#loan
# https://manjushreefinance.com.np/report-viewer/fy-208081-2023-Nov-09-560000#loan
# https://manjushreefinance.com.np/report-viewer/second-quaterly-report-2079-80---published#other-services
# https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2078
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2072-73#loan
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2073-74#other-services
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2076-77#loan
# https://manjushreefinance.com.np/uploads/acf/1563255279.pdf
# https://manjushreefinance.com.np/detail/71/saving-plus-
# https://manjushreefinance.com.np/detail/400/premium-saving-#deposit
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2064-65
# https://manjushreefinance.com.np/detail/240/bishesh-bachat-#loan
# https://manjushreefinance.com.np/other-services#digital-banking
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2074-75#deposit
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2078-79-as-per-nfrs#other-services
# https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2080#deposit
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2077-78#deposit
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2077-78-as-per-nfrs#digital-banking
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2076-77#deposit
# https://manjushreefinance.com.np/digital-banking#other-services
# https://manjushreefinance.com.np/report-viewer/fifth-annual-report#deposit
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2076-77-as-per-nrfs#digital-banking
# https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2078#digital-banking
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2077-78-as-per-nfrs
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2069-70#deposit
# https://manjushreefinance.com.np/team/management#digital-banking
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2075-76#loan
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2075-76
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2075-76#loan
# https://manjushreefinance.com.np/detail/489/16th-agm-notice-2023-Dec-20-183200#loan
# https://manjushreefinance.com.np/detail/489/16th-agm-notice-2023-Dec-20-183200#digital-banking
# https://manjushreefinance.com.np/uploads/acf/1563255306.pdf
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2076-77#other-services
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2070-71#deposit
# https://manjushreefinance.com.np/detail/155/ips-&-clearing#digital-banking
# https://manjushreefinance.com.np/report-viewer/ninth-annual-report#deposit
# https://manjushreefinance.com.np/reports/annual-reports#digital-banking
# https://manjushreefinance.com.np/rates/fee-and-charges#deposit
# https://manjushreefinance.com.np/downloads#other-services
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-208081-published-2024-Jan-21-413600#deposit
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2079-80---published#other-services
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-208081-published-2024-Apr-21-000100#other-services
# https://manjushreefinance.com.np/detail/149/share-loan#loan
# https://manjushreefinance.com.np/report-viewer/ninth-annual-report#other-services
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-208081-as-per-nfrs-2024-May-07-005100
# https://manjushreefinance.com.np/uploads/acf/1563255123.pdf
# https://manjushreefinance.com.np/detail/511/web-banking-notice-2024-Jun-11-076100#deposit
# https://manjushreefinance.com.np/news-event#other-services
# https://manjushreefinance.com.np/team/information-officer#digital-banking
# https://manjushreefinance.com.np/detail/71/saving-plus-#other-services
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2079-80-as-per-nrfs#digital-banking
# https://manjushreefinance.com.np/report-viewer/basel-ii-report--as-of-ashad-2077
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2079-80-as-per-nrfs#loan
# https://manjushreefinance.com.np/report-viewer/twelve-annual-report-%282075-76%29#other-services
# https://manjushreefinance.com.np/detail/136/mobile-banking
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-208081-published-2024-Apr-21-000100
# https://manjushreefinance.com.np/other-services#loan
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-208081-published-2024-Jan-21-413600
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2070-71#deposit
# https://manjushreefinance.com.np/report-viewer/sixteenth-annual-report-2079080-2024-Jan-08-500900#other-services
# https://manjushreefinance.com.np/report-viewer/second--quarterly-report--2068-69#loan
# https://manjushreefinance.com.np/report-viewer/second--quarterly-report--2068-69#digital-banking
# https://manjushreefinance.com.np/news-event#loan
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2066-67#deposit
# https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-poush-2077#other-services
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2070-71#loan
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2074-75#deposit
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2064-65#deposit
# https://manjushreefinance.com.np/report-viewer/basel--ii-report-for-the-chaitra--2077
# https://manjushreefinance.com.np/uploads/acf/1566890488.pdf
# https://manjushreefinance.com.np/uploads/acf/1563094778.pdf
# https://manjushreefinance.com.np/detail/70/normal-saving
# https://manjushreefinance.com.np/report-viewer/fourteenth-annual-report-%282077-78%29#other-services
# https://manjushreefinance.com.np/report-viewer/eighth-annual-report#other-services
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2077-78-as-per-nrfs#deposit
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2072-73#digital-banking
# https://manjushreefinance.com.np/report-viewer/second-quaterly-report-2079-80---published#digital-banking
# https://manjushreefinance.com.np/branch#loan
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2066-67#deposit
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2078-79-as-per-nfrs#digital-banking
# https://manjushreefinance.com.np/detail/150/education-loan#loan
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2066-67#other-services
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2075-76#deposit
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2069-70
# https://manjushreefinance.com.np/deposit#other-services
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2071-72#digital-banking
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2069-70
# https://manjushreefinance.com.np/uploads/acf/1563255911.pdf
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2067-68
# https://manjushreefinance.com.np/report-viewer/eleventh-annual-report#other-services
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2066-67#other-services
# https://manjushreefinance.com.np/report-viewer/basel-ii-report-for-the-ashoj-2078
# https://manjushreefinance.com.np/report-viewer/basel--ii-report-for-the-chaitra--2077#digital-banking
# https://manjushreefinance.com.np/uploads/acf/1563255513.pdf
# https://manjushreefinance.com.np/report-viewer/thirteenth-annual-report#loan
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2071-72#deposit
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2072-73
# https://manjushreefinance.com.np#digital-banking-3
# https://manjushreefinance.com.np/detail/232/connectip#digital-banking
# https://manjushreefinance.com.np/uploads/acf/1672916364.pdf
# https://manjushreefinance.com.np/team/compliance-officer
# https://manjushreefinance.com.np/report-viewer/basel-ii-report-as-of-ashadh-2079#deposit
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2076-77-as-per-nrfs
# https://manjushreefinance.com.np/feedback
# https://manjushreefinance.com.np/detail/515/manjushree-talab-bachat-khata-2024-Jul-16-238600#other-services
# https://manjushreefinance.com.np/uploads/acf/61275800.pdf
# https://manjushreefinance.com.np/report-viewer/ninth-annual-report
# https://manjushreefinance.com.np/rates/fee-and-charges#digital-banking
# https://manjushreefinance.com.np/products#digital-banking
# https://manjushreefinance.com.np/report-viewer/basel-ll-report-as-of-chaitra-2078#loan
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-208081-as-per-nfrs-2024-Jan-26-058000#loan
# https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Jul-16-2024-Aug-14-657300#deposit
# https://manjushreefinance.com.np/video-tutorial
# https://manjushreefinance.com.np/detail/152/auto-loan#deposit
# https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Dec-15-2024-Aug-14-978800#other-services
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2078-79-as-per-nfrs#other-services
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2068-69#deposit
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2069-70#loan
# https://manjushreefinance.com.np/team/management#deposit
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2078-79---published#digital-banking
# https://manjushreefinance.com.np/report-viewer/basel-ii-report--as-of-ashad-2077#digital-banking
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-208081-as-per-nfrs-2023-Nov-09-367900#loan
# https://manjushreefinance.com.np/downloads#loan
# https://manjushreefinance.com.np/detail/73/children-saving#loan
# https://manjushreefinance.com.np/news-event#digital-banking
# https://manjushreefinance.com.np/detail/149/share-loan#digital-banking
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2075-76
# https://manjushreefinance.com.np/report-viewer/basel--ii-report-as-of-asar--2078#loan
# https://manjushreefinance.com.np/report-viewer/thirteenth-annual-report#other-services
# https://manjushreefinance.com.np/page/company-profile#other-services
# https://manjushreefinance.com.np/rates/fee-and-charges
# https://manjushreefinance.com.np/report-viewer/fy-208081-2024-Dec-15-2024-Aug-14-978800#deposit
# https://manjushreefinance.com.np/report-viewer/manjusghree#deposit
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2078-79-as-per-nfrs#digital-banking
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2065-66#digital-banking
# https://manjushreefinance.com.np/report-viewer/basel--ii-report-for-the-chaitra--2077#loan
# https://manjushreefinance.com.np/report-viewer/seventh-annual-report#digital-banking
# https://manjushreefinance.com.np/atm#digital-banking
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-208081-as-per-nfrs-2024-May-07-005100#digital-banking
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2076-77#digital-banking
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2075-76-as-per-nrfs#loan
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2075-76#loan
# https://manjushreefinance.com.np/detail/490/election-schedule-2023-Dec-27-925900
# https://manjushreefinance.com.np/report-viewer/fourth-annual-report#loan
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2076-77-as-per-nrfs
# https://manjushreefinance.com.np/detail/156/business-loan#deposit
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2076-77#loan
# https://manjushreefinance.com.np/detail/409/naulo-remit-saving#deposit
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2067-68
# https://manjushreefinance.com.np/detail/70/normal-saving#loan
# https://manjushreefinance.com.np/detail/139/remittance#other-services
# https://manjushreefinance.com.np/report-viewer/basel-ii-report-for-the-ashoj-2078#other-services
# https://manjushreefinance.com.np/uploads/acf/1660820436.pdf
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2072-73#digital-banking
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2073-74#digital-banking
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2077-78-as-per-nrfs#other-services
# https://manjushreefinance.com.np/uploads/acf/1563095056.pdf
# https://manjushreefinance.com.np/detail/149/share-loan#other-services
# https://manjushreefinance.com.np/uploads/acf/1683631796.pdf
# https://manjushreefinance.com.np/uploads/acf/29416400.pdf
# https://manjushreefinance.com.np/detail/512/web-banking-2024-Jun-11-235100#other-services
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2079-80---published#digital-banking
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2067-68#digital-banking
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2072-73#deposit
# https://manjushreefinance.com.np/uploads/acf/1619504991.pdf
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2073-74#deposit
# https://manjushreefinance.com.np/detail/240/bishesh-bachat-
# https://manjushreefinance.com.np/report-viewer/twelve-annual-report-%282075-76%29#loan
# https://manjushreefinance.com.np/detail/226/home-loan#loan
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2066-67#digital-banking
# https://manjushreefinance.com.np/detail/136/mobile-banking#loan
# https://manjushreefinance.com.np/reports/basel-reports
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2067-68#deposit
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2066-67
# https://manjushreefinance.com.np/report-viewer/fourth-quarterly-report-2067-68#deposit
# https://manjushreefinance.com.np/detail/400/premium-saving-#other-services
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-2070-71#other-services
# https://manjushreefinance.com.np/report-viewer/fourth-quaterly-report-2078-79-published#digital-banking
# https://manjushreefinance.com.np/team/information-officer#other-services
# https://manjushreefinance.com.np/uploads/acf/1563255820.pdf
# https://manjushreefinance.com.np/uploads/acf/1566897841.pdf
# https://manjushreefinance.com.np/report-viewer/first-quarterly-report-208081-as-per-nfrs-2023-Nov-09-367900#other-services
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2065-66#deposit
# https://manjushreefinance.com.np/report-viewer/third-quarterly-report-2075-76#deposit
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2069-70#loan
# https://manjushreefinance.com.np/report-viewer/second-quarterly-report-2073-74

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=links, columns=['URL'])

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv('./Links/Manjushree.csv', index=False)

# %%
def fetch_page_content(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        title = soup.title.string if soup.title else 'No Title'
        paragraphs = [p.get_text() for p in soup.find_all('p')]
        return {
            'url': url,
            'title': title,
            'content': '\n'.join(paragraphs)
        }
    except requests.RequestException:
        return None

# %%
def organize_website_contents(base_url, links):
    contents = {}
    for link in links:
        content = fetch_page_content(link)
        if content:
            contents[link] = content
    return contents

# %%
organized_contents = organize_website_contents(site_url, links)

# %%
from langchain.prompts import PromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate, ChatPromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage

# %%
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
from bs4 import BeautifulSoup
import requests

# %%
# from langchain_groq import ChatGroq
from langchain_nvidia_ai_endpoints import ChatNVIDIA

# %%
# llm = ChatGroq(
#     model='llama-3.1-70b-versatile',
#     max_tokens=None,
#     max_retries=3,
#     timeout=None,
#     temperature=0.4
# )

# llm = ChatGroq(
#     model='llama3-groq-70b-8192-tool-use-preview',
#     max_tokens=None,
#     max_retries=3,
#     timeout=None,
#     temperature=0.2
# )

llm = ChatNVIDIA(
    model='meta/llama-3.1-405b-instruct',
    max_tokens=None,
    max_retries=3,
    temperature=0.1,
    timeout=None
)

# %%
# Define the system message content
system_template = """
# HTML Content Scraper Bot

You are an AI assistant designed to extract and structure content from HTML. Your task is to analyze the provided HTML body and return clean, highly structured data in a single, comprehensive JSON format. Follow these guidelines:

1. Input: You will receive the HTML body of a web page.

2. Output: Provide a single JSON object containing all structured data extracted from the HTML.

3. Extraction Rules:
   - Identify and extract the main content, ignoring navigation menus, footers, and sidebars.
   - Extract the page title and any global metadata.
   - Identify and extract all products or main sections, including their titles, descriptions, features, associated images, and any hyperlinks or attachment links.
   - Preserve the hierarchical structure of the content.
   - Extract all relevant hyperlinks, including their text and URLs.
   - Identify and extract any attachment links, such as PDFs or other downloadable files.

4. Data Cleaning:
   - Remove any HTML tags from the extracted text, except for hyperlinks which should be preserved in a structured format.
   - Decode HTML entities (e.g., &amp; to &, &quot; to ").
   - Trim leading and trailing whitespace from all extracted text.
   - Normalize whitespace within text (replace multiple spaces with a single space).

5. Output Structure:
   Provide the extracted data in the following JSON format:

   {{
     "title": "string",
     "metadata": {{
       "author": "string or null",
       "date": "string or null",
       "tags": ["string"]
     }},
     "products": [
       {{
         "title": "string",
         "description": "string",
         "features": [
           {{
             "type": "string (e.g., 'unordered')",
             "items": [
               {{
                 "text": "string",
                 "links": [
                   {{
                     "text": "string",
                     "url": "string"
                   }}
                 ]
               }}
             ]
           }}
         ],
         "images": [
           {{
             "url": "string",
             "alt_text": "string"
           }}
         ],
         "attachments": [
           {{
             "name": "string",
             "url": "string"
           }}
         ],
         "links": [
           {{
             "text": "string",
             "url": "string"
           }}
         ]
       }}
     ],
     "global_links": [
       {{
         "text": "string",
         "url": "string"
       }}
     ]
   }}

6. Error Handling:
   - If you encounter any issues parsing the HTML or extracting content, include an "errors" field in the JSON output with relevant error messages.

7. Additional Notes:
   - Ensure all relevant information, including hyperlinks and attachment links, is captured in a single JSON structure.
   - If certain fields are not present for some products, include them as null or empty arrays/objects as appropriate.
   - Preserve the original order of content elements as they appear in the HTML.

Remember, your goal is to provide a single, comprehensive, and highly structured JSON that accurately represents all the main content of the web page, including all relevant links and attachments, making it easy for further processing or analysis.
"""

# Create SystemMessagePromptTemplate
system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)

# Create HumanMessagePromptTemplate
human_template = "HTML content to scrape:\n{html_content}\n\nPlease provide a single, comprehensive, and highly structured JSON output based on the above HTML content, following the structure and guidelines provided. Include all relevant hyperlinks and attachment links."
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

# Combine SystemMessagePromptTemplate and HumanMessagePromptTemplate
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])

# %%
chain = chat_prompt | llm

# %%
import pandas as pd
linksDf = pd.read_csv('./Links/siteLinks.csv')
links=linksDf['links'].tolist()

# %%
for i, val in enumerate(links):
    if val == 'https://www.nicasiabank.com/branches-list/':
        print(i)
# Out:
# 26

# %%
links = links[27:]

# %%
import time
import random

# %%
siteData = {}

# %%
siteData['https://www.nicasiabank.com/branches-list/'] = 'Reduce length of the page/handle later'

# %%
for link in links:
    try:
        resp = requests.get(link)
        resp.raise_for_status()
        soup = BeautifulSoup(resp.text, 'html.parser')
        intervals = [10,20,30]
        i = 0
        while True:
            try:
                botResp = chain.invoke({
                    'html_content': soup
                })
                siteData[f'{link}'] = botResp.content
                break  # Exit the retry loop if successful
            except Exception as e:
                if 'reduce the length of the messages' in str(e):
                    siteData[f'{link}'] = f'{e}'
                    break
                print(f"Failed to invoke chain for {link}: {e}. Retrying in {intervals[i]} seconds...")
                if i >= 2:
                    i = 2
                else:
                    i += 1
                time.sleep(intervals[i])  # Wait before retrying
        # print(botResp.content)
    except requests.RequestException:
        print("Failed to Extract information.")
        siteData[f'{link}'] = 'Error'

# %%
import pickle

with open('./SiteData/data.pickle', 'wb') as f:
    pickle.dump(siteData, f)

# %%
for i,url in enumerate(siteData.keys()):
    with open(f'./SiteLLMParsedText/{i}_text.txt','w') as f:
        f.write(siteData[f'{url}'])

# %%
### well this is not a proper way to parse HTML pages, as we would reach TOKEN limit very quickly and not resource efficient

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from bs4.element import Tag, NavigableString

# %%
links = pd.read_csv('./Links/siteLinks.csv')

# %%
links = links['links'].to_list()

# %%
class TreeNode:
    def __init__(self, tag=None, text=None):
        self.tag = tag
        self.text = text
        self.children = []

    def __repr__(self, level=0):
        indent = " " * (level * 2)
        if self.tag:
            repr_str = f"{indent}<{self.tag}>"
        else:
            repr_str = f"{indent}{self.text}"
        for child in self.children:
            repr_str += "\n" + child.__repr__(level + 1)
        if self.tag:
            repr_str += f"\n{indent}</{self.tag}>"
        return repr_str

def html_to_tree(html):
    soup = BeautifulSoup(html, 'lxml')
    return parse_element(soup.html)

def parse_element(element):
    if isinstance(element, Tag):
        node = TreeNode(tag=element.name)
        for child in element.children:
            child_node = parse_element(child)
            if child_node:
                node.children.append(child_node)
        return node
    elif isinstance(element, NavigableString):
        return TreeNode(text=element.strip())
    return None

# %%
for link in links:
    page = requests.get(link)
    page.raise_for_status()
    linkHTML = page.text
    print(html_to_tree(linkHTML))
    break
# Out:
# <html>
#   <head>
#     <meta>
#     </meta>
#     <title>
#       NIC ASIA BANK LIMITED
#     </title>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <link>
#     </link>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <meta>
#     </meta>
#     <link>
#     </link>
#     <link>
#     </link>
#     <link>
#     </link>
#     <link>
#     </link>
#     <link>
#     </link>
#     <noscript>
#     </noscript>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#     <script>
#     </script>
#   </head>
#   <body>
#     <div>
#       <main>
#         <nav>
#           <a>
#             NIC Asia Bank Homepage
#           </a>
#           <a>
#             Loans
#           </a>
#           <a>
#             Savings
#           </a>
#           <a>
#             Cards
#           </a>
#           <a>
#             Dispute Claim
#           </a>
#           <a>
#             Gallery
#           </a>
#           <a>
#             CSR
#           </a>
#           <a>
#             About Us
#           </a>
#           <a>
#             Contact Us
#           </a>
#           <a>
#             Corporate Govarnance
#           </a>
#           <a>
#             Feedback Form
#           </a>
#           <a>
#             Downloads
#           </a>
#           <a>
#             AGM Related
#           </a>
#           <a>
#             Investor Relation
#           </a>
#           <a>
#             Offers
#           </a>
#           <a>
#             Login
#           </a>
#           <a>
#             Signup
#           </a>
#           <a>
#             ATM and Branches
#           </a>
#           <a>
#             Gold Rates
#           </a>
#           <a>
#             Forex Rates
#           </a>
#           <a>
#             Interest Rates
#           </a>
#           <a>
#             Sitemap
#           </a>
#           <a>
#             Tutorial
#           </a>
#           <a>
#             Loan Eligibility
#           </a>
#           <a>
#             FAQ
#           </a>
#           <a>
#             Benefit Calculator
#           </a>
#         </nav>
#         <div>
#           <header>
#             <div>
#             </div>
#             <div>
#               <div>
#                 <div>
#                   <a>
#                   </a>
#                 </div>
#                 <figure>
#                 </figure>
#               </div>
#               <button>
#                 <svg>
#                   <g>
#                     <path>
#                     </path>
#                     <path>
#                     </path>
#                   </g>
#                 </svg>
#                 <div>
#                   Menu
#                 </div>
#               </button>
#             </div>
#           </header>
#         </div>
#         <h1>
#           NIC ASIA Bank Homepage
#         </h1>
#         <div>
#           <div>
#             <img>
#             </img>
#           </div>
#         </div>
#         <div>
#           <div>
#             <div>
#               <div>
#                 <div>
#                   <div>
#                   </div>
#                   <div>
#                   </div>
#                   <div>
#                   </div>
#                 </div>
#                 <div>
#                   <div>
#                     <div>
#                       <div>
#                         <div>
#                         </div>
#                         <div>
#                         </div>
#                         <div>
#                         </div>
#                         <div>
#                         </div>
#                         <div>
#                         </div>
#                         <div>
#                         </div>
#                         <div>
#                         </div>
#                       </div>
#                     </div>
#                   </div>
#                 </div>
#               </div>
#             </div>
#             <div>
#               <a>
#                 <button>
#                   <img>
#                   </img>
#                   Go To iServe
#                 </button>
#               </a>
#               <div>
#                 <a>
#                   <div>
#                     <img>
#                     </img>
#                     <div>
#                       <div>
#                         MoBank Web
#                       </div>
#                       <div>
#                         <p>
#                           Log In
#                           <svg>
#                             <path>
#                             </path>
#                           </svg>
#                         </p>
#                       </div>
#                     </div>
#                   </div>
#                 </a>
#                 <a>
#                   <div>
#                     <img>
#                     </img>
#                     <div>
#                       <div>
#                         Branch Network
#                       </div>
#                       <div>
#                         <p>
#                           Find Us Here
#                           <svg>
#                             <path>
#                             </path>
#                           </svg>
#                         </p>
#                       </div>
#                     </div>
#                   </div>
#                 </a>
#                 <a>
#                   <div>
#                     <img>
#                     </img>
#                     <div>
#                       <div>
#                         Schedule an Appointment
#                       </div>
#                       <div>
#                         <p>
#                           Book an Appointment
#                           <svg>
#                             <path>
#                             </path>
#                           </svg>
#                         </p>
#                       </div>
#                     </div>
#                   </div>
#                 </a>
#               </div>
#             </div>
#           </div>
#         </div>
#         <div>
#         </div>
#         <div>
#         </div>
#         <div>
#         </div>
#         <div>
#         </div>
#         <div>
#         </div>
#         <div>
#           <div>
#             <h2>
#               Were you looking for something?
#             </h2>
#           </div>
#           <div>
#             <div>
#               <img>
#               </img>
#             </div>
#           </div>
#         </div>
#         <div>
#           <div>
#             <footer>
#               <div>
#               </div>
#               <div>
#                 <section>
#                   <div>
#                     0
#                   </div>
#                 </section>
#               </div>
#               <div>
#                 <div>
#                   <div>
#                     <span>
#                       <p>
#                         Copyright ©
#
#                         2024
#
#                         .
#
#
#                         <a>
#                           NIC ASIA Bank Limited
#                         </a>
#
#
#                         | All Rights Reserved.
#                       </p>
#                     </span>
#                     <span>
#                       Crafted By:
#
#
#                       <a>
#                         Amnil Technologies Private Limited
#                       </a>
#                     </span>
#                   </div>
#                 </div>
#               </div>
#             </footer>
#           </div>
#         </div>
#         <div>
#           <ul>
#             <li>
#               <a>
#                 <svg>
#                   <path>
#                   </path>
#                 </svg>
#                 <span>
#                   Branches and Atms
#                 </span>
#               </a>
#             </li>
#           </ul>
#           <div>
#           </div>
#           <button>
#             <span>
#             </span>
#           </button>
#         </div>
#         <div>
#         </div>
#       </main>
#       <div>
#         <img>
#         </img>
#       </div>
#     </div>
#     <script>
#       {"props":{"__N_SSG":true,"pageProps":{"dehydratedState":{"mutations":[],"queries":[{"state":{"data":{"resCod":"200","resDesc":"Frontend Banner Information.","data":{"banner":[{"id":"229dd4f5-f3f4-48e5-b66e-b022408628b8","name":"Personal Banking - MoBank","title":"Now, Bank is in our Hand, with \u003cspan class=\"text-danger\"\u003e NIC ASIA MoBank\u003c/span\u003e","title_np":"अब हातहात बैंक,  \u003cspan class=\"text-danger\"\u003eNIC ASIA मोबैंक\u003c/span\u003e","subtitle":"NIC ASIA MoBank","bannerbackgroundcolor":{"id":"158d2a51-f2e0-11ec-bb66-02420a000808","name":"White","code":"#ffffff"},"subtitle_np":"NIC ASIA मोबैंक","image":"uploads/Banner/MoBank final.jpeg","first_button_text":"Download Our MoBank","first_button_text_np":"MoBank डाउनलोड गर्नुहोस्","first_button_url":"https://play.google.com/store/apps/details?id=com.f1soft.nicasiamobilebanking\u0026pli=1","second_button_text":null,"second_button_text_np":null,"second_button_url":null,"status":true,"show_first_button":true,"show_second_button":true,"order":1,"menus":[{"id":"decfe0ef-7b65-49c7-871e-e3b19b874551","name":"Individual","slug":"individual","headerImage":null,"firstButtonText":null,"firstButtonTextNp":null,"firstButtonLink":null,"secondButtonText":null,"secondButtonTextNp":null,"secondButtonLink":null},{"id":"8eda9705-1826-4785-809d-ca0f4c3b6f77","name":"Business","slug":"business","headerImage":null,"firstButtonText":null,"firstButtonTextNp":null,"firstButtonLink":null,"secondButtonText":null,"secondButtonTextNp":null,"secondButtonLink":null}],"bannerType":null,"video":null,"videoSource":null,"is_featured_in_homepage":null},{"id":"1c7f9bea-fb79-4342-8cbd-fa30cb015b75","name":"iServe","title":"A Complete Digital Services Platform","title_np":null,"subtitle":"iServe","bannerbackgroundcolor":null,"subtitle_np":null,"image":"uploads/Banner/iserve-banner.png","first_button_text":"Go To iServe","first_button_text_np":null,"first_button_url":"https://iserve.nicasiabank.com/payment-services","second_button_text":null,"second_button_text_np":null,"second_button_url":null,"status":true,"show_first_button":true,"show_second_button":true,"order":2,"menus":[{"id":"decfe0ef-7b65-49c7-871e-e3b19b874551","name":"Individual","slug":"individual","headerImage":null,"firstButtonText":null,"firstButtonTextNp":null,"firstButtonLink":null,"secondButtonText":null,"secondButtonTextNp":null,"secondButtonLink":null},{"id":"8eda9705-1826-4785-809d-ca0f4c3b6f77","name":"Business","slug":"business","headerImage":null,"firstButtonText":null,"firstButtonTextNp":null,"firstButtonLink":null,"secondButtonText":null,"secondButtonTextNp":null,"secondButtonLink":null},{"id":"22cf3d93-8b91-46fe-b8b4-e62e16da279c","name":"Digital Universe","slug":"digital-universe","headerImage":null,"firstButtonText":null,"firstButtonTextNp":null,"firstButtonLink":null,"secondButtonText":null,"secondButtonTextNp":null,"secondButtonLink":null}],"bannerType":null,"video":null,"videoSource":null,"is_featured_in_homepage":null},{"id":"6ebc5c91-362f-4d5a-b659-ca0f63b396a4","name":"Personal Banking - Merchant Offer","title":"NIC ASIA is providing \u003cspan class=\"text-danger\"\u003e3,000+ Discount Offers\u003c/span\u003e","title_np":"NIC ASIA ले \u003cspan class=\"text-danger\"\u003e३,००० भन्दा बढी छुट अफरहरू\u003c/span\u003e प्रदान गर्दै छ","subtitle":"Merchant Offer","bannerbackgroundcolor":{"id":"158d2a51-f2e0-11ec-bb66-02420a000808","name":"White","code":"#ffffff"},"subtitle_np":"मर्चेन्ट अफर","image":"uploads/Banner/Home Page/Merchant Offer.png","first_button_text":"Grab Our Offer","first_button_text_np":"अफरको मज्जा लिनुहोस्","first_button_url":"/offers","second_button_text":null,"second_button_text_np":null,"second_button_url":null,"status":true,"show_first_button":true,"show_second_button":true,"order":4,"menus":[{"id":"decfe0ef-7b65-49c7-871e-e3b19b874551","name":"Individual","slug":"individual","headerImage":null,"firstButtonText":null,"firstButtonTextNp":null,"firstButtonLink":null,"secondButtonText" ...
#     </script>
#   </body>
# </html>
